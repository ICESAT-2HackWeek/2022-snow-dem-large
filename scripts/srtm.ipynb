# %% [markdown]
# based on https://github.com/tkrajina/srtm.py

# %%
pip install SRTM.py
# Out:
# Requirement already satisfied: SRTM.py in /srv/conda/envs/notebook/lib/python3.9/site-packages (0.3.7)
# Requirement already satisfied: requests in /srv/conda/envs/notebook/lib/python3.9/site-packages (from SRTM.py) (2.27.1)
# Requirement already satisfied: certifi>=2017.4.17 in /srv/conda/envs/notebook/lib/python3.9/site-packages (from requests->SRTM.py) (2021.10.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /srv/conda/envs/notebook/lib/python3.9/site-packages (from requests->SRTM.py) (1.26.9)
# Requirement already satisfied: idna<4,>=2.5 in /srv/conda/envs/notebook/lib/python3.9/site-packages (from requests->SRTM.py) (3.3)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /srv/conda/envs/notebook/lib/python3.9/site-packages (from requests->SRTM.py) (2.0.12)
# Note: you may need to restart the kernel to use updated packages.

# %%
import srtm
import numpy as np
import matplotlib.pyplot as plt

# %%
# make matplotlib interactive
# %matplotlib widget

# %%
geo_elevation_data = srtm.get_data()

# %%
image_size = 500

# coordinates for delft
latitude_interval = (52,53)
longitude_interval = (4, 5)

# get data as np array
image2 = geo_elevation_data.get_image((image_size, image_size), latitude_interval, longitude_interval, 300, mode='array')

plt.imshow(image2)
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
